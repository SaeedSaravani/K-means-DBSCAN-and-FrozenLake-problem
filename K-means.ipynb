# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
from sklearn.cluster import KMeans

# %%
image = img.imread('holi-festival.jpg')
plt.figure(figsize = (15,8))
plt.imshow(image)

# %%
def drawing(image,k):
    x, y, z = image.shape
    image_2d = image.reshape(x*y, z)
    kmeans = KMeans(n_clusters=k, random_state=0).fit(image_2d)
    cluster_centers = kmeans.cluster_centers_
    cluster_labels = kmeans.labels_
    plt.figure(figsize = (15,8))
    img = cluster_centers[cluster_labels].reshape(x, y, z)
    plt.title(f"output for k={k}")
    plt.imshow(np.uint8(img))
    return 0

# %%
ks = [15,20]
imgs=[]
for k in ks:
    img = drawing(image,k)
    imgs.append(img)

# %%
image = img.imread('bird.jpg')
plt.figure(figsize = (15,8))
plt.imshow(image)

# %%
ks = [2,3,4,5,6,10,15,20]
imgs=[]
for k in ks:
    img = drawing(image,k)
    imgs.append(img)
